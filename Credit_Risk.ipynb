# %%
# !git config --global user.name
"shrxshio"
# !git config --global user.email
"shreeshverse@gmail.com"
# Out:
# 'shreeshverse@gmail.com'

# %%
# !git clone https://github.com/shrxshio/Credit-Risk-Assessement-using-SHAP.git
# Out:
# fatal: destination path 'Credit-Risk-Assessement-using-SHAP' already exists and is not an empty directory.

# %%
# !pwd
# !ls -la /content
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Sep 25 10:06 .
# drwxr-xr-x 1 root root 4096 Sep 25 09:37 ..
# drwxr-xr-x 4 root root 4096 Sep 16 13:26 .config
# drwxr-xr-x 3 root root 4096 Sep 25 10:06 Credit-Risk-Assessement-using-SHAP
# drwxr-xr-x 1 root root 4096 Sep 16 13:26 sample_data

# %%
# !REPO=$(find /content -maxdepth 1 -type d -name "Credit*" -print -quit) && echo "$REPO" && ls -la "$REPO"
# Out:
# /content/Credit-Risk-Assessement-using-SHAP
# total 12
# drwxr-xr-x 3 root root 4096 Sep 25 10:06 .
# drwxr-xr-x 1 root root 4096 Sep 25 10:06 ..
# drwxr-xr-x 7 root root 4096 Sep 25 10:06 .git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -name "Untitled22.ipynb" 2>/dev/null
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled22.ipynb

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Untitled22.ipynb" "/content/Credit-Risk-Assessment-using-SHAP/"
# Out:
# cp: cannot create regular file '/content/Credit-Risk-Assessment-using-SHAP/': Not a directory
